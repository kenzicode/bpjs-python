# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:/Users/user/Documents/DATA ANALYST/Tingkat Kepuasaan Hidup Terhadap Sepuluh Aspek Kehidupan Menurut Provinsi 2014.csv", sep=';')

# %%
data.head()
# Out:
#          Provinsi Kondisi Rumah dan Aset Pendapatan Rumah Tangga Pekerjaan  \
# 0            ACEH                  64.37                   61.98     64.75
# 1  SUMATERA UTARA                  65.76                   61.98     63.20
# 2  SUMATERA BARAT                  63.92                   61.43     64.21
# 3            RIAU                  66.75                   63.36     65.78
# 4           JAMBI                  68.53                   66.40     69.23
#
#   Kondisi Keamanan Keadaan Lingkungan Hubungan Sosial  \
# 0            77.23              73.23           74.65
# 1            76.11              73.63           73.00
# 2            77.03              74.48           73.10
# 3            75.06              72.33           74.93
# 4            79.45              76.08           76.79
#
#   Ketersediaan Waktu Luang Keharmonisan Keluarga Pendidikan Kesehatan
# 0                    71.80                 79.00      59.28     68.56
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 11 columns):
# Provinsi                    35 non-null object
# Kondisi Rumah dan Aset      35 non-null object
# Pendapatan Rumah Tangga     35 non-null object
# Pekerjaan                   35 non-null object
# Kondisi Keamanan            35 non-null object
# Keadaan Lingkungan          35 non-null object
# Hubungan Sosial             35 non-null object
# Ketersediaan Waktu Luang    35 non-null object
# Keharmonisan Keluarga       35 non-null object
# Pendidikan                  35 non-null object
# Kesehatan                   35 non-null object
# dtypes: object(11)
# memory usage: 3.4+ KB

# %%
data.describe()
# Out:
#               Provinsi Kondisi Rumah dan Aset Pendapatan Rumah Tangga  \
# count               35                     35                      35
# unique              35                     35                      33
# top     SUMATERA BARAT                  65.45                   68.20
# freq                 1                      1                       2
#
#        Pekerjaan Kondisi Keamanan Keadaan Lingkungan Hubungan Sosial  \
# count         35               35                 35              35
# unique        34               35                 33              35
# top        63.20            79.85              74.86           75.09
# freq           2                1                  2               1
#
#        Ketersediaan Waktu Luang Keharmonisan Keluarga Pendidikan Kesehatan
# count                        35                    35         35        35
# unique                       34                    34         33        34
# ...

# %%
data.head(38)
# Out:
#                 Provinsi Kondisi Rumah dan Aset Pendapatan Rumah Tangga  \
# 0                   ACEH                  64.37                   61.98
# 1         SUMATERA UTARA                  65.76                   61.98
# 2         SUMATERA BARAT                  63.92                   61.43
# 3                   RIAU                  66.75                   63.36
# 4                  JAMBI                  68.53                   66.40
# 5       SUMATERA SELATAN                  64.45                   61.79
# 6               BENGKULU                  60.43                   58.18
# 7                LAMPUNG                  63.95                   62.54
# 8   KEP. BANGKA BELITUNG                  67.69                   63.01
# 9              KEP. RIAU                  72.81                   68.75
# 10           DKI JAKARTA                  69.66                   65.56
# 11            JAWA BARAT                  64.15                   62.04
# ...

# %%
data = data.dropna()

# %%
data.head(36)
# Out:
#                 Provinsi Kondisi Rumah dan Aset Pendapatan Rumah Tangga  \
# 0                   ACEH                  64.37                   61.98
# 1         SUMATERA UTARA                  65.76                   61.98
# 2         SUMATERA BARAT                  63.92                   61.43
# 3                   RIAU                  66.75                   63.36
# 4                  JAMBI                  68.53                   66.40
# 5       SUMATERA SELATAN                  64.45                   61.79
# 6               BENGKULU                  60.43                   58.18
# 7                LAMPUNG                  63.95                   62.54
# 8   KEP. BANGKA BELITUNG                  67.69                   63.01
# 9              KEP. RIAU                  72.81                   68.75
# 10           DKI JAKARTA                  69.66                   65.56
# 11            JAWA BARAT                  64.15                   62.04
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 34
# Data columns (total 11 columns):
# Provinsi                    35 non-null object
# Kondisi Rumah dan Aset      35 non-null object
# Pendapatan Rumah Tangga     35 non-null object
# Pekerjaan                   35 non-null object
# Kondisi Keamanan            35 non-null object
# Keadaan Lingkungan          35 non-null object
# Hubungan Sosial             35 non-null object
# Ketersediaan Waktu Luang    35 non-null object
# Keharmonisan Keluarga       35 non-null object
# Pendidikan                  35 non-null object
# Kesehatan                   35 non-null object
# dtypes: object(11)
# memory usage: 3.3+ KB

# %%
columns = ['Kondisi Rumah dan Aset', 'Pendapatan Rumah Tangga', 'Pekerjaan', 'Kondisi Keamanan', 'Keadaan Lingkungan', 'Hubungan Sosial', 'Ketersediaan Waktu Luang', 'Keharmonisan Keluarga', 'Pendidikan', 'Kesehatan']

# %%
for column in columns:
    temp = pd.to_numeric(data[column], errors='coerce')
    temp = pd.DataFrame(temp)
    data = data.drop([column], axis=1)
    data = data.join(temp)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 34
# Data columns (total 11 columns):
# Provinsi                    35 non-null object
# Kondisi Rumah dan Aset      34 non-null float64
# Pendapatan Rumah Tangga     34 non-null float64
# Pekerjaan                   34 non-null float64
# Kondisi Keamanan            34 non-null float64
# Keadaan Lingkungan          34 non-null float64
# Hubungan Sosial             34 non-null float64
# Ketersediaan Waktu Luang    34 non-null float64
# Keharmonisan Keluarga       34 non-null float64
# Pendidikan                  34 non-null float64
# Kesehatan                   34 non-null float64
# dtypes: float64(10), object(1)
# memory usage: 4.5+ KB

# %%
data.describe()
# Out:
#        Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  Pekerjaan  \
# count               34.000000                34.000000  34.000000
# mean                65.102059                63.673824  66.982353
# std                  3.731013                 2.680865   2.703205
# min                 56.010000                58.180000  61.660000
# 25%                 63.785000                61.995000  65.025000
# 50%                 65.245000                63.080000  66.395000
# 75%                 67.407500                65.555000  69.100000
# max                 72.810000                68.750000  73.420000
#
#        Kondisi Keamanan  Keadaan Lingkungan  Hubungan Sosial  \
# count         34.000000           34.000000        34.000000
# mean          77.250294           74.785294        75.142941
# std            2.345167            2.025446         1.928761
# min           69.480000           69.750000        68.910000
# 25%           76.420000           73.687500        74.082500
# ...

# %%
data.head()
# Out:
#          Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  Pekerjaan  \
# 0            ACEH                   64.37                    61.98      64.75
# 1  SUMATERA UTARA                   65.76                    61.98      63.20
# 2  SUMATERA BARAT                   63.92                    61.43      64.21
# 3            RIAU                   66.75                    63.36      65.78
# 4           JAMBI                   68.53                    66.40      69.23
#
#    Kondisi Keamanan  Keadaan Lingkungan  Hubungan Sosial  \
# 0             77.23               73.23            74.65
# 1             76.11               73.63            73.00
# 2             77.03               74.48            73.10
# 3             75.06               72.33            74.93
# 4             79.45               76.08            76.79
#
#    Ketersediaan Waktu Luang  Keharmonisan Keluarga  Pendidikan  Kesehatan
# 0                     71.80                  79.00       59.28      68.56
# ...

# %%
data[data.Provinsi != 'KALIMANTAN UTARA']
# Out:
#                 Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  \
# 0                   ACEH                   64.37                    61.98
# 1         SUMATERA UTARA                   65.76                    61.98
# 2         SUMATERA BARAT                   63.92                    61.43
# 3                   RIAU                   66.75                    63.36
# 4                  JAMBI                   68.53                    66.40
# 5       SUMATERA SELATAN                   64.45                    61.79
# 6               BENGKULU                   60.43                    58.18
# 7                LAMPUNG                   63.95                    62.54
# 8   KEP. BANGKA BELITUNG                   67.69                    63.01
# 9              KEP. RIAU                   72.81                    68.75
# 10           DKI JAKARTA                   69.66                    65.56
# 11            JAWA BARAT                   64.15                    62.04
# ...

# %%
data.describe()
# Out:
#        Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  Pekerjaan  \
# count               34.000000                34.000000  34.000000
# mean                65.102059                63.673824  66.982353
# std                  3.731013                 2.680865   2.703205
# min                 56.010000                58.180000  61.660000
# 25%                 63.785000                61.995000  65.025000
# 50%                 65.245000                63.080000  66.395000
# 75%                 67.407500                65.555000  69.100000
# max                 72.810000                68.750000  73.420000
#
#        Kondisi Keamanan  Keadaan Lingkungan  Hubungan Sosial  \
# count         34.000000           34.000000        34.000000
# mean          77.250294           74.785294        75.142941
# std            2.345167            2.025446         1.928761
# min           69.480000           69.750000        68.910000
# 25%           76.420000           73.687500        74.082500
# ...

# %%
data[data.Provinsi != 'INDONESIA']
# Out:
#                 Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  \
# 0                   ACEH                   64.37                    61.98
# 1         SUMATERA UTARA                   65.76                    61.98
# 2         SUMATERA BARAT                   63.92                    61.43
# 3                   RIAU                   66.75                    63.36
# 4                  JAMBI                   68.53                    66.40
# 5       SUMATERA SELATAN                   64.45                    61.79
# 6               BENGKULU                   60.43                    58.18
# 7                LAMPUNG                   63.95                    62.54
# 8   KEP. BANGKA BELITUNG                   67.69                    63.01
# 9              KEP. RIAU                   72.81                    68.75
# 10           DKI JAKARTA                   69.66                    65.56
# 11            JAWA BARAT                   64.15                    62.04
# ...

# %%
data.describe()
# Out:
#        Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  Pekerjaan  \
# count               34.000000                34.000000  34.000000
# mean                65.102059                63.673824  66.982353
# std                  3.731013                 2.680865   2.703205
# min                 56.010000                58.180000  61.660000
# 25%                 63.785000                61.995000  65.025000
# 50%                 65.245000                63.080000  66.395000
# 75%                 67.407500                65.555000  69.100000
# max                 72.810000                68.750000  73.420000
#
#        Kondisi Keamanan  Keadaan Lingkungan  Hubungan Sosial  \
# count         34.000000           34.000000        34.000000
# mean          77.250294           74.785294        75.142941
# std            2.345167            2.025446         1.928761
# min           69.480000           69.750000        68.910000
# 25%           76.420000           73.687500        74.082500
# ...

# %%
data
# Out:
#                 Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  \
# 0                   ACEH                   64.37                    61.98
# 1         SUMATERA UTARA                   65.76                    61.98
# 2         SUMATERA BARAT                   63.92                    61.43
# 3                   RIAU                   66.75                    63.36
# 4                  JAMBI                   68.53                    66.40
# 5       SUMATERA SELATAN                   64.45                    61.79
# 6               BENGKULU                   60.43                    58.18
# 7                LAMPUNG                   63.95                    62.54
# 8   KEP. BANGKA BELITUNG                   67.69                    63.01
# 9              KEP. RIAU                   72.81                    68.75
# 10           DKI JAKARTA                   69.66                    65.56
# 11            JAWA BARAT                   64.15                    62.04
# ...

# %%
data = data[data.Provinsi != 'INDONESIA']

# %%
data = data[data.Provinsi != 'KALIMANTAN UTARA']

# %%
data
# Out:
#                 Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  \
# 0                   ACEH                   64.37                    61.98
# 1         SUMATERA UTARA                   65.76                    61.98
# 2         SUMATERA BARAT                   63.92                    61.43
# 3                   RIAU                   66.75                    63.36
# 4                  JAMBI                   68.53                    66.40
# 5       SUMATERA SELATAN                   64.45                    61.79
# 6               BENGKULU                   60.43                    58.18
# 7                LAMPUNG                   63.95                    62.54
# 8   KEP. BANGKA BELITUNG                   67.69                    63.01
# 9              KEP. RIAU                   72.81                    68.75
# 10           DKI JAKARTA                   69.66                    65.56
# 11            JAWA BARAT                   64.15                    62.04
# ...

# %%
data.describe()
# Out:
#        Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  Pekerjaan  \
# count               33.000000                33.000000  33.000000
# mean                65.104848                63.691515  66.979394
# std                  3.788826                 2.720415   2.745061
# min                 56.010000                58.180000  61.660000
# 25%                 63.740000                61.980000  65.010000
# 50%                 65.450000                63.070000  66.380000
# 75%                 67.440000                65.560000  69.160000
# max                 72.810000                68.750000  73.420000
#
#        Kondisi Keamanan  Keadaan Lingkungan  Hubungan Sosial  \
# count         33.000000           33.000000        33.000000
# mean          77.269091           74.783030        75.168788
# std            2.378926            2.056807         1.952677
# min           69.480000           69.750000        68.910000
# 25%           76.350000           73.630000        74.050000
# ...

# %%
the_best = data.sort_values(by=['Kondisi Keamanan'], ascending=False)

# %%
the_best.head()
# Out:
#              Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  \
# 30             MALUKU                   69.56                    68.35
# 16               BALI                   66.04                    64.09
# 20  KALIMANTAN TENGAH                   66.17                    65.54
# 26   SULAWESI SELATAN                   65.45                    64.21
# 4               JAMBI                   68.53                    66.40
#
#     Pekerjaan  Kondisi Keamanan  Keadaan Lingkungan  Hubungan Sosial  \
# 30      73.42             81.75               79.21            78.13
# 16      69.29             79.97               76.37            74.02
# 20      67.96             79.85               75.63            76.42
# 26      68.30             79.82               77.31            76.05
# 4       69.23             79.45               76.08            76.79
#
#     Ketersediaan Waktu Luang  Keharmonisan Keluarga  Pendidikan  Kesehatan
# ...

# %%
datasum = data.sum()

# %%
datasum
# Out:
# Provinsi                    ACEHSUMATERA UTARASUMATERA BARATRIAUJAMBISUMAT...
# Kondisi Rumah dan Aset                                                2148.46
# Pendapatan Rumah Tangga                                               2101.82
# Pekerjaan                                                             2210.32
# Kondisi Keamanan                                                      2549.88
# Keadaan Lingkungan                                                    2467.84
# Hubungan Sosial                                                       2480.57
# Ketersediaan Waktu Luang                                              2382.46
# Keharmonisan Keluarga                                                 2638.92
# Pendidikan                                                            1935.54
# Kesehatan                                                             2303.97
# dtype: object

# %%
data.sum(axis=0)
# Out:
# Provinsi                    ACEHSUMATERA UTARASUMATERA BARATRIAUJAMBISUMAT...
# Kondisi Rumah dan Aset                                                2148.46
# Pendapatan Rumah Tangga                                               2101.82
# Pekerjaan                                                             2210.32
# Kondisi Keamanan                                                      2549.88
# Keadaan Lingkungan                                                    2467.84
# Hubungan Sosial                                                       2480.57
# Ketersediaan Waktu Luang                                              2382.46
# Keharmonisan Keluarga                                                 2638.92
# Pendidikan                                                            1935.54
# Kesehatan                                                             2303.97
# dtype: object

# %%
data.sum(axis=1)
# Out:
# 0     694.85
# 1     689.37
# 2     687.15
# 3     699.79
# 4     724.75
# 5     693.85
# 6     686.19
# 7     697.12
# 8     699.08
# 9     741.26
# 10    702.92
# 11    689.73
# 12    693.81
# 13    722.08
# 14    704.72
# 15    692.36
# 16    707.54
# 17    702.65
# 18    675.93
# 19    695.35
# 20    718.90
# 21    715.43
# 22    725.76
# 24    721.00
# 25    699.89
# 26    714.61
# 27    701.14
# 28    704.66
# 29    689.56
# 30    745.82
# 31    722.34
# 32    717.06
# 33    643.11
# dtype: float64

# %%
df = data.insert(1, "Total", True)

# %%
df

# %%
data
# Out:
#                 Provinsi  Total  Kondisi Rumah dan Aset  \
# 0                   ACEH   True                   64.37
# 1         SUMATERA UTARA   True                   65.76
# 2         SUMATERA BARAT   True                   63.92
# 3                   RIAU   True                   66.75
# 4                  JAMBI   True                   68.53
# 5       SUMATERA SELATAN   True                   64.45
# 6               BENGKULU   True                   60.43
# 7                LAMPUNG   True                   63.95
# 8   KEP. BANGKA BELITUNG   True                   67.69
# 9              KEP. RIAU   True                   72.81
# 10           DKI JAKARTA   True                   69.66
# 11            JAWA BARAT   True                   64.15
# 12           JAWA TENGAH   True                   63.74
# 13         DI YOGYAKARTA   True                   68.59
# 14            JAWA TIMUR   True                   65.87
# 15                BANTEN   True                   65.04
# ...

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                 Provinsi  Total  Kondisi Rumah dan Aset  \
# 0                   ACEH   True                   64.37
# 1         SUMATERA UTARA   True                   65.76
# 2         SUMATERA BARAT   True                   63.92
# 3                   RIAU   True                   66.75
# 4                  JAMBI   True                   68.53
# 5       SUMATERA SELATAN   True                   64.45
# 6               BENGKULU   True                   60.43
# 7                LAMPUNG   True                   63.95
# 8   KEP. BANGKA BELITUNG   True                   67.69
# 9              KEP. RIAU   True                   72.81
# 10           DKI JAKARTA   True                   69.66
# 11            JAWA BARAT   True                   64.15
# 12           JAWA TENGAH   True                   63.74
# 13         DI YOGYAKARTA   True                   68.59
# 14            JAWA TIMUR   True                   65.87
# 15                BANTEN   True                   65.04
# ...

# %%
data = data.drop("Total", axis=1)

# %%
data
# Out:
#                 Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  \
# 0                   ACEH                   64.37                    61.98
# 1         SUMATERA UTARA                   65.76                    61.98
# 2         SUMATERA BARAT                   63.92                    61.43
# 3                   RIAU                   66.75                    63.36
# 4                  JAMBI                   68.53                    66.40
# 5       SUMATERA SELATAN                   64.45                    61.79
# 6               BENGKULU                   60.43                    58.18
# 7                LAMPUNG                   63.95                    62.54
# 8   KEP. BANGKA BELITUNG                   67.69                    63.01
# 9              KEP. RIAU                   72.81                    68.75
# 10           DKI JAKARTA                   69.66                    65.56
# 11            JAWA BARAT                   64.15                    62.04
# ...

# %%
total = data.sum(axis=1)

# %%
total
# Out:
# 0     694.85
# 1     689.37
# 2     687.15
# 3     699.79
# 4     724.75
# 5     693.85
# 6     686.19
# 7     697.12
# 8     699.08
# 9     741.26
# 10    702.92
# 11    689.73
# 12    693.81
# 13    722.08
# 14    704.72
# 15    692.36
# 16    707.54
# 17    702.65
# 18    675.93
# 19    695.35
# 20    718.90
# 21    715.43
# 22    725.76
# 24    721.00
# 25    699.89
# 26    714.61
# 27    701.14
# 28    704.66
# 29    689.56
# 30    745.82
# 31    722.34
# 32    717.06
# 33    643.11
# dtype: float64

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                 Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  \
# 0                   ACEH                   64.37                    61.98
# 1         SUMATERA UTARA                   65.76                    61.98
# 2         SUMATERA BARAT                   63.92                    61.43
# 3                   RIAU                   66.75                    63.36
# 4                  JAMBI                   68.53                    66.40
# 5       SUMATERA SELATAN                   64.45                    61.79
# 6               BENGKULU                   60.43                    58.18
# 7                LAMPUNG                   63.95                    62.54
# 8   KEP. BANGKA BELITUNG                   67.69                    63.01
# 9              KEP. RIAU                   72.81                    68.75
# 10           DKI JAKARTA                   69.66                    65.56
# 11            JAWA BARAT                   64.15                    62.04
# ...

# %%
df.insert(11, "Total", total, True)

# %%
df
# Out:
#                 Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  \
# 0                   ACEH                   64.37                    61.98
# 1         SUMATERA UTARA                   65.76                    61.98
# 2         SUMATERA BARAT                   63.92                    61.43
# 3                   RIAU                   66.75                    63.36
# 4                  JAMBI                   68.53                    66.40
# 5       SUMATERA SELATAN                   64.45                    61.79
# 6               BENGKULU                   60.43                    58.18
# 7                LAMPUNG                   63.95                    62.54
# 8   KEP. BANGKA BELITUNG                   67.69                    63.01
# 9              KEP. RIAU                   72.81                    68.75
# 10           DKI JAKARTA                   69.66                    65.56
# 11            JAWA BARAT                   64.15                    62.04
# ...

# %%
data = df.drop("Total", axis=1)

# %%
data
# Out:
#                 Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  \
# 0                   ACEH                   64.37                    61.98
# 1         SUMATERA UTARA                   65.76                    61.98
# 2         SUMATERA BARAT                   63.92                    61.43
# 3                   RIAU                   66.75                    63.36
# 4                  JAMBI                   68.53                    66.40
# 5       SUMATERA SELATAN                   64.45                    61.79
# 6               BENGKULU                   60.43                    58.18
# 7                LAMPUNG                   63.95                    62.54
# 8   KEP. BANGKA BELITUNG                   67.69                    63.01
# 9              KEP. RIAU                   72.81                    68.75
# 10           DKI JAKARTA                   69.66                    65.56
# 11            JAWA BARAT                   64.15                    62.04
# ...

# %%
df = pd.DataFrame(data)

# %%
total = df.mean(axis=1)

# %%
total
# Out:
# 0     69.485
# 1     68.937
# 2     68.715
# 3     69.979
# 4     72.475
# 5     69.385
# 6     68.619
# 7     69.712
# 8     69.908
# 9     74.126
# 10    70.292
# 11    68.973
# 12    69.381
# 13    72.208
# 14    70.472
# 15    69.236
# 16    70.754
# 17    70.265
# 18    67.593
# 19    69.535
# 20    71.890
# 21    71.543
# 22    72.576
# 24    72.100
# 25    69.989
# 26    71.461
# 27    70.114
# 28    70.466
# 29    68.956
# 30    74.582
# 31    72.234
# 32    71.706
# 33    64.311
# dtype: float64

# %%
df = df.insert(11, "Total", total, True)

# %%
df

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                 Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  \
# 0                   ACEH                   64.37                    61.98
# 1         SUMATERA UTARA                   65.76                    61.98
# 2         SUMATERA BARAT                   63.92                    61.43
# 3                   RIAU                   66.75                    63.36
# 4                  JAMBI                   68.53                    66.40
# 5       SUMATERA SELATAN                   64.45                    61.79
# 6               BENGKULU                   60.43                    58.18
# 7                LAMPUNG                   63.95                    62.54
# 8   KEP. BANGKA BELITUNG                   67.69                    63.01
# 9              KEP. RIAU                   72.81                    68.75
# 10           DKI JAKARTA                   69.66                    65.56
# 11            JAWA BARAT                   64.15                    62.04
# ...

# %%
best = df.sort_values(by=['Total'], ascending=False)

# %%
best.head()
# Out:
#             Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  \
# 30            MALUKU                   69.56                    68.35
# 9          KEP. RIAU                   72.81                    68.75
# 22  KALIMANTAN TIMUR                   71.69                    68.20
# 4              JAMBI                   68.53                    66.40
# 31      MALUKU UTARA                   67.44                    68.20
#
#     Pekerjaan  Kondisi Keamanan  Keadaan Lingkungan  Hubungan Sosial  \
# 30      73.42             81.75               79.21            78.13
# 9       72.37             79.36               75.34            76.50
# 22      70.11             77.87               73.37            75.09
# 4       69.23             79.45               76.08            76.79
# 31      69.97             76.35               74.86            76.59
#
#     Ketersediaan Waktu Luang  Keharmonisan Keluarga  Pendidikan  Kesehatan  \
# ...

# %%
df
# Out:
#                 Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  \
# 0                   ACEH                   64.37                    61.98
# 1         SUMATERA UTARA                   65.76                    61.98
# 2         SUMATERA BARAT                   63.92                    61.43
# 3                   RIAU                   66.75                    63.36
# 4                  JAMBI                   68.53                    66.40
# 5       SUMATERA SELATAN                   64.45                    61.79
# 6               BENGKULU                   60.43                    58.18
# 7                LAMPUNG                   63.95                    62.54
# 8   KEP. BANGKA BELITUNG                   67.69                    63.01
# 9              KEP. RIAU                   72.81                    68.75
# 10           DKI JAKARTA                   69.66                    65.56
# 11            JAWA BARAT                   64.15                    62.04
# ...

# %%
df.head()
# Out:
#          Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  Pekerjaan  \
# 0            ACEH                   64.37                    61.98      64.75
# 1  SUMATERA UTARA                   65.76                    61.98      63.20
# 2  SUMATERA BARAT                   63.92                    61.43      64.21
# 3            RIAU                   66.75                    63.36      65.78
# 4           JAMBI                   68.53                    66.40      69.23
#
#    Kondisi Keamanan  Keadaan Lingkungan  Hubungan Sosial  \
# 0             77.23               73.23            74.65
# 1             76.11               73.63            73.00
# 2             77.03               74.48            73.10
# 3             75.06               72.33            74.93
# 4             79.45               76.08            76.79
#
#    Ketersediaan Waktu Luang  Keharmonisan Keluarga  Pendidikan  Kesehatan  \
# 0                     71.80                  79.00       59.28      68.56
# ...

# %%
best
# Out:
#                 Provinsi  Kondisi Rumah dan Aset  Pendapatan Rumah Tangga  \
# 30                MALUKU                   69.56                    68.35
# 9              KEP. RIAU                   72.81                    68.75
# 22      KALIMANTAN TIMUR                   71.69                    68.20
# 4                  JAMBI                   68.53                    66.40
# 31          MALUKU UTARA                   67.44                    68.20
# 13         DI YOGYAKARTA                   68.59                    65.18
# 24        SULAWESI UTARA                   68.12                    66.20
# 20     KALIMANTAN TENGAH                   66.17                    65.54
# 32           PAPUA BARAT                   65.65                    66.90
# 21    KALIMANTAN SELATAN                   67.31                    66.16
# 26      SULAWESI SELATAN                   65.45                    64.21
# 16                  BALI                   66.04                    64.09
# ...

# %%
best = best.reset_index()

# %%
best
# Out:
#     index              Provinsi  Kondisi Rumah dan Aset  \
# 0      30                MALUKU                   69.56
# 1       9             KEP. RIAU                   72.81
# 2      22      KALIMANTAN TIMUR                   71.69
# 3       4                 JAMBI                   68.53
# 4      31          MALUKU UTARA                   67.44
# 5      13         DI YOGYAKARTA                   68.59
# 6      24        SULAWESI UTARA                   68.12
# 7      20     KALIMANTAN TENGAH                   66.17
# 8      32           PAPUA BARAT                   65.65
# 9      21    KALIMANTAN SELATAN                   67.31
# 10     26      SULAWESI SELATAN                   65.45
# 11     16                  BALI                   66.04
# 12     14            JAWA TIMUR                   65.87
# 13     28             GORONTALO                   63.20
# 14     10           DKI JAKARTA                   69.66
# 15     17   NUSA TENGGARA BARAT                   62.23
# ...

# %%
kepuasan = best

# %%
kepuasan
# Out:
#     index              Provinsi  Kondisi Rumah dan Aset  \
# 0      30                MALUKU                   69.56
# 1       9             KEP. RIAU                   72.81
# 2      22      KALIMANTAN TIMUR                   71.69
# 3       4                 JAMBI                   68.53
# 4      31          MALUKU UTARA                   67.44
# 5      13         DI YOGYAKARTA                   68.59
# 6      24        SULAWESI UTARA                   68.12
# 7      20     KALIMANTAN TENGAH                   66.17
# 8      32           PAPUA BARAT                   65.65
# 9      21    KALIMANTAN SELATAN                   67.31
# 10     26      SULAWESI SELATAN                   65.45
# 11     16                  BALI                   66.04
# 12     14            JAWA TIMUR                   65.87
# 13     28             GORONTALO                   63.20
# 14     10           DKI JAKARTA                   69.66
# 15     17   NUSA TENGGARA BARAT                   62.23
# ...

# %%
rawpidana = pd.read_csv("C:/Users/user/Documents/DATA ANALYST/Risiko Penduduk Terkena Tindak Pidana 2014.csv", sep=";")

# %%
rawpidana
# Out:
#               Unnamed: 0                                         Unnamed: 1
# 0      Kepolisian Daerah  Risiko Penduduk Terkena Tindak Pidana (Per 100...
# 1                   ACEH                                             158.00
# 2         SUMATERA UTARA                                             268.00
# 3         SUMATERA BARAT                                             298.00
# 4                   RIAU                                             157.00
# 5                  JAMBI                                             230.00
# 6       SUMATERA SELATAN                                             290.00
# 7               BENGKULU                                             215.00
# 8                LAMPUNG                                              99.00
# 9   KEP. BANGKA BELITUNG                                             134.00
# 10             KEP. RIAU                                             240.00
# ...

# %%
rawpidana.reset_index()
# Out:
#     index            Unnamed: 0  \
# 0       0     Kepolisian Daerah
# 1       1                  ACEH
# 2       2        SUMATERA UTARA
# 3       3        SUMATERA BARAT
# 4       4                  RIAU
# 5       5                 JAMBI
# 6       6      SUMATERA SELATAN
# 7       7              BENGKULU
# 8       8               LAMPUNG
# 9       9  KEP. BANGKA BELITUNG
# 10     10             KEP. RIAU
# 11     11            METRO JAYA
# 12     12            JAWA BARAT
# 13     13           JAWA TENGAH
# 14     14         DI YOGYAKARTA
# 15     15            JAWA TIMUR
# 16     16                BANTEN
# 17     17                  BALI
# 18     18   NUSA TENGGARA BARAT
# 19     19   NUSA TENGGARA TIMUR
# 20     20      KALIMANTAN BARAT
# 21     21     KALIMANTAN TENGAH
# 22     22    KALIMANTAN SELATAN
# 23     23      KALIMANTAN TIMUR
# 24     24      KALIMANTAN UTARA
# 25     25        SULAWESI UTARA
# 26     26       SULAWESI TENGAH
# 27     27      SULAWESI SELATAN
# ...

# %%
rawpidana = rawpidana[["Unnamed: 0", "Unnamed: 1"]]

# %%
rawpidana
# Out:
#               Unnamed: 0                                         Unnamed: 1
# 0      Kepolisian Daerah  Risiko Penduduk Terkena Tindak Pidana (Per 100...
# 1                   ACEH                                             158.00
# 2         SUMATERA UTARA                                             268.00
# 3         SUMATERA BARAT                                             298.00
# 4                   RIAU                                             157.00
# 5                  JAMBI                                             230.00
# 6       SUMATERA SELATAN                                             290.00
# 7               BENGKULU                                             215.00
# 8                LAMPUNG                                              99.00
# 9   KEP. BANGKA BELITUNG                                             134.00
# 10             KEP. RIAU                                             240.00
# ...

# %%
rawpidana.drop(0, axis=0)
# Out:
#               Unnamed: 0 Unnamed: 1
# 1                   ACEH     158.00
# 2         SUMATERA UTARA     268.00
# 3         SUMATERA BARAT     298.00
# 4                   RIAU     157.00
# 5                  JAMBI     230.00
# 6       SUMATERA SELATAN     290.00
# 7               BENGKULU     215.00
# 8                LAMPUNG      99.00
# 9   KEP. BANGKA BELITUNG     134.00
# 10             KEP. RIAU     240.00
# 11            METRO JAYA     186.00
# 12            JAWA BARAT      71.00
# 13           JAWA TENGAH      49.00
# 14         DI YOGYAKARTA     201.00
# 15            JAWA TIMUR      37.00
# 16                BANTEN     115.00
# 17                  BALI     123.00
# 18   NUSA TENGGARA BARAT     156.00
# 19   NUSA TENGGARA TIMUR     131.00
# 20      KALIMANTAN BARAT     179.00
# 21     KALIMANTAN TENGAH     124.00
# 22    KALIMANTAN SELATAN     156.00
# 23      KALIMANTAN TIMUR     230.00
# 24      KALIMANTAN UTARA          -
# 25        SULAWESI UTARA     263.00
# ...

# %%
rawpidana.drop(36, axis=0)
# Out:
#               Unnamed: 0                                         Unnamed: 1
# 0      Kepolisian Daerah  Risiko Penduduk Terkena Tindak Pidana (Per 100...
# 1                   ACEH                                             158.00
# 2         SUMATERA UTARA                                             268.00
# 3         SUMATERA BARAT                                             298.00
# 4                   RIAU                                             157.00
# 5                  JAMBI                                             230.00
# 6       SUMATERA SELATAN                                             290.00
# 7               BENGKULU                                             215.00
# 8                LAMPUNG                                              99.00
# 9   KEP. BANGKA BELITUNG                                             134.00
# 10             KEP. RIAU                                             240.00
# ...

# %%
rawpidana.drop(24, axis=0)
# Out:
#               Unnamed: 0                                         Unnamed: 1
# 0      Kepolisian Daerah  Risiko Penduduk Terkena Tindak Pidana (Per 100...
# 1                   ACEH                                             158.00
# 2         SUMATERA UTARA                                             268.00
# 3         SUMATERA BARAT                                             298.00
# 4                   RIAU                                             157.00
# 5                  JAMBI                                             230.00
# 6       SUMATERA SELATAN                                             290.00
# 7               BENGKULU                                             215.00
# 8                LAMPUNG                                              99.00
# 9   KEP. BANGKA BELITUNG                                             134.00
# 10             KEP. RIAU                                             240.00
# ...

# %%
rawpidana = rawpidana.drop(24, axis=0)

# %%
rawpidana
# Out:
#               Unnamed: 0                                         Unnamed: 1
# 0      Kepolisian Daerah  Risiko Penduduk Terkena Tindak Pidana (Per 100...
# 1                   ACEH                                             158.00
# 2         SUMATERA UTARA                                             268.00
# 3         SUMATERA BARAT                                             298.00
# 4                   RIAU                                             157.00
# 5                  JAMBI                                             230.00
# 6       SUMATERA SELATAN                                             290.00
# 7               BENGKULU                                             215.00
# 8                LAMPUNG                                              99.00
# 9   KEP. BANGKA BELITUNG                                             134.00
# 10             KEP. RIAU                                             240.00
# ...

# %%
rawpidana.columns = ["Provinsi", "Risiko"]

# %%
rawpidana
# Out:
#                 Provinsi                                             Risiko
# 0      Kepolisian Daerah  Risiko Penduduk Terkena Tindak Pidana (Per 100...
# 1                   ACEH                                             158.00
# 2         SUMATERA UTARA                                             268.00
# 3         SUMATERA BARAT                                             298.00
# 4                   RIAU                                             157.00
# 5                  JAMBI                                             230.00
# 6       SUMATERA SELATAN                                             290.00
# 7               BENGKULU                                             215.00
# 8                LAMPUNG                                              99.00
# 9   KEP. BANGKA BELITUNG                                             134.00
# 10             KEP. RIAU                                             240.00
# ...

# %%
merge = pd.merge(kepuasan, rawpidana, on='Provinsi')

# %%
merge
# Out:
#     index              Provinsi  Kondisi Rumah dan Aset  \
# 0      30                MALUKU                   69.56
# 1       9             KEP. RIAU                   72.81
# 2      22      KALIMANTAN TIMUR                   71.69
# 3       4                 JAMBI                   68.53
# 4      31          MALUKU UTARA                   67.44
# 5      13         DI YOGYAKARTA                   68.59
# 6      24        SULAWESI UTARA                   68.12
# 7      20     KALIMANTAN TENGAH                   66.17
# 8      32           PAPUA BARAT                   65.65
# 9      21    KALIMANTAN SELATAN                   67.31
# 10     26      SULAWESI SELATAN                   65.45
# 11     16                  BALI                   66.04
# 12     14            JAWA TIMUR                   65.87
# 13     28             GORONTALO                   63.20
# 14     17   NUSA TENGGARA BARAT                   62.23
# 15     27     SULAWESI TENGGARA                   61.25
# ...

# %%
mergedata = merge.drop(merge.index[8])

# %%
mergedata = merge.drop(merge.index[26])

# %%
mergedata
# Out:
#     index              Provinsi  Kondisi Rumah dan Aset  \
# 0      30                MALUKU                   69.56
# 1       9             KEP. RIAU                   72.81
# 2      22      KALIMANTAN TIMUR                   71.69
# 3       4                 JAMBI                   68.53
# 4      31          MALUKU UTARA                   67.44
# 5      13         DI YOGYAKARTA                   68.59
# 6      24        SULAWESI UTARA                   68.12
# 7      20     KALIMANTAN TENGAH                   66.17
# 8      32           PAPUA BARAT                   65.65
# 9      21    KALIMANTAN SELATAN                   67.31
# 10     26      SULAWESI SELATAN                   65.45
# 11     16                  BALI                   66.04
# 12     14            JAWA TIMUR                   65.87
# 13     28             GORONTALO                   63.20
# 14     17   NUSA TENGGARA BARAT                   62.23
# 15     27     SULAWESI TENGGARA                   61.25
# ...

# %%
mergedata = mergedata.drop(mergedata.index[8])

# %%
mergedata
# Out:
#     index              Provinsi  Kondisi Rumah dan Aset  \
# 0      30                MALUKU                   69.56
# 1       9             KEP. RIAU                   72.81
# 2      22      KALIMANTAN TIMUR                   71.69
# 3       4                 JAMBI                   68.53
# 4      31          MALUKU UTARA                   67.44
# 5      13         DI YOGYAKARTA                   68.59
# 6      24        SULAWESI UTARA                   68.12
# 7      20     KALIMANTAN TENGAH                   66.17
# 9      21    KALIMANTAN SELATAN                   67.31
# 10     26      SULAWESI SELATAN                   65.45
# 11     16                  BALI                   66.04
# 12     14            JAWA TIMUR                   65.87
# 13     28             GORONTALO                   63.20
# 14     17   NUSA TENGGARA BARAT                   62.23
# 15     27     SULAWESI TENGGARA                   61.25
# 16     25       SULAWESI TENGAH                   62.68
# ...

# %%
mergedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 31
# Data columns (total 14 columns):
# index                       30 non-null int64
# Provinsi                    30 non-null object
# Kondisi Rumah dan Aset      30 non-null float64
# Pendapatan Rumah Tangga     30 non-null float64
# Pekerjaan                   30 non-null float64
# Kondisi Keamanan            30 non-null float64
# Keadaan Lingkungan          30 non-null float64
# Hubungan Sosial             30 non-null float64
# Ketersediaan Waktu Luang    30 non-null float64
# Keharmonisan Keluarga       30 non-null float64
# Pendidikan                  30 non-null float64
# Kesehatan                   30 non-null float64
# Total                       30 non-null float64
# Risiko                      30 non-null object
# dtypes: float64(11), int64(1), object(2)
# memory usage: 3.5+ KB

# %%
temp = pd.to_numeric(mergedata["Risiko"], errors='coerce')

# %%
temp = pd.DataFrame(temp)

# %%
mergedata = mergedata.drop(["Risiko"], axis=1)

# %%
mergedata = mergedata.join(temp)

# %%
mergedata.plot(kind='bar', x='Provinsi', y='Kondisi Keamanan', figsize=(12,8))

# %%
mergedata.plot(kind='bar', x='Provinsi', y='Kondisi Rumah dan Aset', figsize=(12,8))

# %%
mergedata.plot(kind='bar', x='Provinsi', y='Kesehatan', figsize=(12,8))

# %%
mergedata.plot(kind='bar', x='Provinsi', y='Keharmonisan Keluarga', figsize=(12,8))

# %%
mergedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 31
# Data columns (total 14 columns):
# index                       30 non-null int64
# Provinsi                    30 non-null object
# Kondisi Rumah dan Aset      30 non-null float64
# Pendapatan Rumah Tangga     30 non-null float64
# Pekerjaan                   30 non-null float64
# Kondisi Keamanan            30 non-null float64
# Keadaan Lingkungan          30 non-null float64
# Hubungan Sosial             30 non-null float64
# Ketersediaan Waktu Luang    30 non-null float64
# Keharmonisan Keluarga       30 non-null float64
# Pendidikan                  30 non-null float64
# Kesehatan                   30 non-null float64
# Total                       30 non-null float64
# Risiko                      30 non-null float64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 4.8+ KB

# %%
mergedata.plot(kind='bar', x='Provinsi', y='Risiko', figsize=(12,8))

# %%
mergedata.plot(kind='bar', x='Provinsi', y=(['Kondisi Keamanan', 'Risiko']), figsize=(12,8))

# %%
plt.plot(mergedata['Ketersediaan Waktu Luang'],'-sc',markersize = 3)
plt.plot(mergedata['Risiko'],'-or',markersize = 3)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
